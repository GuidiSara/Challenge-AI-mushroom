# %%
# !pip3 install -r requirements.txt
# Out:
# ...
# Obtaining networkx from git+https://github.com/GuidiSara/networkx.git@06ef187506c895797992f4e19d4bca9d3d2aae10#egg=networkx (from -r requirements.txt (line 5))
#   Skipping because already up-to-date.
# ...
#   Attempting uninstall: networkx
#     Found existing installation: networkx 2.5
#     Uninstalling networkx-2.5:
#       Successfully uninstalled networkx-2.5
#   Running setup.py develop for networkx
# ...

# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_confusion_matrix
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %% [markdown]
# # Import dataset

# %%
test = pd.read_csv('./test.csv')

# %%
train = pd.read_csv('./train.csv')

# %% [markdown]
# # Dataset visualization

# %% [markdown]
# Describe test

# %%
test.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   1300      1300        1300      1300    1300  1300            1300
# unique     2         5           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq     673       592         529       366     749   560            1266
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          1300      1300       1300  ...                     1300
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           1099       914        270  ...                      783
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    1300                   1300      1300       1300
# unique                      9                      9         1          4
# ...

# %% [markdown]
# Describe training

# %%
train.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   5199      5199        5199      5199    5199  5199            5199
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    2692      2364        2073      1457    3053  2273            5065
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          5199      5199       5199  ...                     5199
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           4352      3582       1128  ...                     3161
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    5199                   5199      5199       5199
# unique                      9                      9         1          4
# ...

# %% [markdown]
# Head training

# %%
train.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           y         n       f    y               f
# 1     e         f           s         n       f    n               f
# 2     e         k           f         g       f    n               f
# 3     e         f           y         n       t    n               f
# 4     p         k           s         n       f    f               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          b  ...                        k
# 1            w         b          p  ...                        f
# 2            w         b          p  ...                        s
# 3            c         b          w  ...                        s
# 4            c         n          b  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      p         p          w
# ...

# %% [markdown]
# Head test

# %%
test.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     e         f           s         g       f    n               f
# 1     p         f           y         n       f    y               f
# 2     e         k           f         g       f    n               f
# 3     p         x           s         n       f    y               f
# 4     p         f           s         n       f    s               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            w         b          p  ...                        f
# 1            c         n          b  ...                        k
# 2            w         b          g  ...                        k
# 3            c         n          b  ...                        k
# 4            c         n          b  ...                        k
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %% [markdown]
# Type train

# %%
train.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %% [markdown]
# Type test

# %%
test.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %% [markdown]
# # Missing values

# %%
train['stalk-root'] = pd.to_numeric(train['stalk-root'], errors='coerce')
test['stalk-root'] = pd.to_numeric(test['stalk-root'], errors='coerce')

# %%
test.dtypes
# Out:
# class                        object
# cap-shape                    object
# cap-surface                  object
# cap-color                    object
# bruises                      object
# odor                         object
# gill-attachment              object
# gill-spacing                 object
# gill-size                    object
# gill-color                   object
# stalk-shape                  object
# stalk-root                  float64
# stalk-surface-above-ring     object
# stalk-surface-below-ring     object
# stalk-color-above-ring       object
# stalk-color-below-ring       object
# veil-type                    object
# veil-color                   object
# ring-number                  object
# ring-type                    object
# spore-print-color            object
# population                   object
# habitat                      object
# dtype: object

# %%
train.dtypes
# Out:
# class                        object
# cap-shape                    object
# cap-surface                  object
# cap-color                    object
# bruises                      object
# odor                         object
# gill-attachment              object
# gill-spacing                 object
# gill-size                    object
# gill-color                   object
# stalk-shape                  object
# stalk-root                  float64
# stalk-surface-above-ring     object
# stalk-surface-below-ring     object
# stalk-color-above-ring       object
# stalk-color-below-ring       object
# veil-type                    object
# veil-color                   object
# ring-number                  object
# ring-type                    object
# spore-print-color            object
# population                   object
# habitat                      object
# dtype: object

# %%
train['stalk-root'] = train['stalk-root'].fillna(0)
test['stalk-root'] = test['stalk-root'].fillna(0)

# %% [markdown]
# # Encoding

# %%
labelEncoder = LabelEncoder()

# %% [markdown]
# Encoding training

# %%
train['class']=labelEncoder.fit_transform(train['class'])
train['cap-shape']=labelEncoder.fit_transform(train['cap-shape'])
train['cap-surface']=labelEncoder.fit_transform(train['cap-surface'])
train['cap-color']=labelEncoder.fit_transform(train['cap-color'])
train['bruises']=labelEncoder.fit_transform(train['bruises'])
train['odor']=labelEncoder.fit_transform(train['odor'])
train['gill-attachment']=labelEncoder.fit_transform(train['gill-attachment'])
train['gill-spacing']=labelEncoder.fit_transform(train['gill-spacing'])
train['gill-size']=labelEncoder.fit_transform(train['gill-size'])
train['gill-color']=labelEncoder.fit_transform(train['gill-color'])
train['stalk-shape']=labelEncoder.fit_transform(train['stalk-shape'])
train['stalk-surface-above-ring']=labelEncoder.fit_transform(train['stalk-surface-above-ring'])
train['stalk-surface-below-ring']=labelEncoder.fit_transform(train['stalk-surface-below-ring'])
train['stalk-color-above-ring']=labelEncoder.fit_transform(train['stalk-color-above-ring'])
train['stalk-color-below-ring']=labelEncoder.fit_transform(train['stalk-color-below-ring'])
train['veil-type']=labelEncoder.fit_transform(train['veil-type'])
train['veil-color']=labelEncoder.fit_transform(train['veil-color'])
train['ring-number']=labelEncoder.fit_transform(train['ring-number'])
train['ring-type']=labelEncoder.fit_transform(train['ring-type'])
train['spore-print-color']=labelEncoder.fit_transform(train['spore-print-color'])
train['population']=labelEncoder.fit_transform(train['population'])
train['veil-color']=labelEncoder.fit_transform(train['veil-color'])
train['habitat']=labelEncoder.fit_transform(train['habitat'])

# %%
train.dtypes
# Out:
# class                         int32
# cap-shape                     int32
# cap-surface                   int32
# cap-color                     int32
# bruises                       int32
# odor                          int32
# gill-attachment               int32
# gill-spacing                  int32
# gill-size                     int32
# gill-color                    int32
# stalk-shape                   int32
# stalk-root                  float64
# stalk-surface-above-ring      int32
# stalk-surface-below-ring      int32
# stalk-color-above-ring        int32
# stalk-color-below-ring        int32
# veil-type                     int32
# veil-color                    int64
# ring-number                   int32
# ring-type                     int32
# spore-print-color             int32
# population                    int32
# habitat                       int32
# dtype: object

# %% [markdown]
# Encoding Test

# %%
test['class']=labelEncoder.fit_transform(test['class'])
test['cap-shape']=labelEncoder.fit_transform(test['cap-shape'])
test['cap-surface']=labelEncoder.fit_transform(test['cap-surface'])
test['cap-color']=labelEncoder.fit_transform(test['cap-color'])
test['bruises']=labelEncoder.fit_transform(test['bruises'])
test['odor']=labelEncoder.fit_transform(test['odor'])
test['gill-attachment']=labelEncoder.fit_transform(test['gill-attachment'])
test['gill-spacing']=labelEncoder.fit_transform(test['gill-spacing'])
test['gill-size']=labelEncoder.fit_transform(test['gill-size'])
test['gill-color']=labelEncoder.fit_transform(test['gill-color'])
test['stalk-shape']=labelEncoder.fit_transform(test['stalk-shape'])
test['stalk-surface-above-ring']=labelEncoder.fit_transform(test['stalk-surface-above-ring'])
test['stalk-surface-below-ring']=labelEncoder.fit_transform(test['stalk-surface-below-ring'])
test['stalk-color-above-ring']=labelEncoder.fit_transform(test['stalk-color-above-ring'])
test['stalk-color-below-ring']=labelEncoder.fit_transform(test['stalk-color-below-ring'])
test['veil-type']=labelEncoder.fit_transform(test['veil-type'])
test['veil-color']=labelEncoder.fit_transform(test['veil-color'])
test['ring-number']=labelEncoder.fit_transform(test['ring-number'])
test['ring-type']=labelEncoder.fit_transform(test['ring-type'])
test['spore-print-color']=labelEncoder.fit_transform(test['spore-print-color'])
test['population']=labelEncoder.fit_transform(test['population'])
test['veil-color']=labelEncoder.fit_transform(test['veil-color'])
test['habitat']=labelEncoder.fit_transform(test['habitat'])

# %%
test.dtypes
# Out:
# class                         int32
# cap-shape                     int32
# cap-surface                   int32
# cap-color                     int32
# bruises                       int32
# odor                          int32
# gill-attachment               int32
# gill-spacing                  int32
# gill-size                     int32
# gill-color                    int32
# stalk-shape                   int32
# stalk-root                  float64
# stalk-surface-above-ring      int32
# stalk-surface-below-ring      int32
# stalk-color-above-ring        int32
# stalk-color-below-ring        int32
# veil-type                     int32
# veil-color                    int64
# ring-number                   int32
# ring-type                     int32
# spore-print-color             int32
# population                    int32
# habitat                       int32
# dtype: object

# %%
train.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            3          4        0     8                1
# 1      0          2            2          4        0     5                1
# 2      0          3            0          3        0     5                1
# 3      0          2            3          4        1     5                1
# 4      1          3            2          4        0     2                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           0  ...                         1
# 1             1          0           7  ...                         0
# 2             1          0           7  ...                         2
# 3             0          0          10  ...                         2
# 4             0          1           0  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %%
test.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      0          1            2          3        0     5                1
# 1      1          1            3          4        0     8                1
# 2      0          2            0          3        0     5                1
# 3      1          4            2          4        0     8                1
# 4      1          1            2          4        0     7                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             1          0           7  ...                         0
# 1             0          1           0  ...                         1
# 2             1          0           2  ...                         1
# 3             0          1           0  ...                         1
# 4             0          1           0  ...                         1
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %% [markdown]
# # Separated dataset from labels

# %%
features = train.columns.drop('class')
x_train = train[features]
y_train = train['class']

# %%
x_test = test[features]
y_test = test['class']

# %% [markdown]
# # Accuracy

# %% [markdown]
# Decision tree

# %%
tree = DecisionTreeClassifier()
tree.fit(x_train, y_train)
tree.fit(x_test, y_test)
print(f'Accuracy of training set: {tree.score(x_train, y_train)*100}%')
print(f'Accuracy of test set: {tree.score(x_train, y_train)*100}%')
# Out:
# Accuracy of training set: 100.0%
# Accuracy of test set: 100.0%

# %% [markdown]
# SVC

# %%
svc = SVC()
svc.fit(x_train, y_train)
y_pred = svc.predict(x_test)
acc_svc_training = round(accuracy_score(y_pred, y_test) * 100, 2)

svc.fit(x_test, y_test)
y_pred = svc.predict(x_test)
acc_svc_test = round(accuracy_score(y_pred, y_test) * 100, 2)

print(f'Accuracy of Training set: {acc_svc_training} %')
print(f'Accuracy of Test set: {acc_svc_test} %')
# Out:
# Accuracy of Training set: 98.23 %
# Accuracy of Test set: 96.08 %
